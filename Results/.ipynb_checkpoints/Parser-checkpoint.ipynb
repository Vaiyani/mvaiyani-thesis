# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
pd.set_option('display.max_columns', None)

# %%
def parse_results(filename:str, mv:bool = False) -> pd.DataFrame:
    "Parse results text filename and creates a pandas DataFrame"
    
    data = defaultdict(list)
    with open(filename) as file:
        for line in file:
            if line == '\n':
                continue
            if line[:3] == 'mse':
                result = line.replace(" ", "").split(',')
                data['MSE'].append(round(float(result[0].split(':')[1]),8))
                data['MAE'].append(round(float(result[1].split(':')[1]),8))
                if not mv:
                    data['RMSE'].append(round(float(result[2].split(':')[1]),8))
                    data['MAPE'].append(round(float(result[3].split(':')[1]),8))
                    data['MSPE'].append(round(float(result[4].split(':')[1]),8))
                    data['RSE'].append(round(float(result[5].split(':')[1]),8))
                    data['R2'].append(round(float(result[6].split(':')[1]),8))
                    data['train_time'].append(round(float(result[7].split(':')[1]),8))
                    data['test_time'].append(round(float(result[8].split(':')[1]),8))
                    if len(result) > 9:
                        data['epochs'].append(round(float(result[9].split(':')[1]),8))
                    else:
                        data['epochs'].append(1)
                    
            else:
                attributes = line.split(sep='_')
#                 print(attributes)
                data['model'].append(attributes[0])
                data['lookback'].append(int(attributes[1].split('-')[1]))
                data['future'].append(int(attributes[3].split('-')[1]))
                data['pos'].append(attributes[5].split('-')[1])
                data['val'].append(attributes[6].split('-')[1])
                data['temp'].append(attributes[7].split('-')[1].split(' ')[0])

    return pd.DataFrame.from_dict(data)

def parse_lstms(filename:str) -> pd.DataFrame:
    "Parse results text filename and creates a pandas DataFrame"
    
    data = defaultdict(list)
    with open(filename) as file:
        for line in file:
            if line == '\n':
                continue
            if line[:3] == 'mse':
                result = line.replace(" ", "").split(',')
                data['MSE'].append(round(float(result[0].split(':')[1]),8))
                data['MAE'].append(round(float(result[1].split(':')[1]),8))
                data['RMSE'].append(round(float(result[2].split(':')[1]),8))
                data['MAPE'].append(round(float(result[3].split(':')[1]),8))
                data['R2'].append(round(float(result[4].split(':')[1]),8))
            else:
                attributes = line.split(sep='_')
                model = attributes[0]
                data['lookback'].append(int(attributes[2].split('-')[1]))
                data['future'].append(int(attributes[3].split('-')[1]))

    return pd.DataFrame.from_dict(data)

def slice_and_dice(formers:pd.DataFrame, lstms: pd.DataFrame) -> pd.DataFrame:
    """."""
    transformer, autoformer, informer = \
    formers[formers['model'] == 'Transformer'].drop('model', axis = 1), \
    formers[formers['model'] == 'Autoformer'].drop('model', axis = 1), \
    formers[formers['model'] == 'Informer'].drop('model', axis = 1),
    df = autoformer.merge(informer, how = "left", on=["lookback", "future", "pos", "val", "temp"], \
                              suffixes=('-Autoformer', '-Informer'))\
                       .merge(transformer, how = "left", on=["lookback", "future", "pos", "val", "temp"], \
                             suffixes=('_ello', '-Transformer'))\
                       .merge(lstms, how="left",  on=["lookback", "future"], suffixes=('-Transformer', '-LSTM'))

    return df

# def compare_uni_multi(uni: pd.DataFrame, mv: pd.DataFrame) -> pd.DataFrame:

# %%
## Univariate ##
uv_formers = parse_results('univariate/formers-original-data.txt').\
                drop_duplicates(subset=['model', 'lookback', 'future', 'pos','val','temp'], keep = 'last')
uv_formers['time_per_epoch'] = uv_formers['train_time']/uv_formers['epochs']
uv_lstms = parse_lstms('univariate/new_results_lstm.txt').\
                drop_duplicates(subset=['lookback', 'future'], keep = 'first')

## multivariate OHLC##
mv_formers = parse_results('multivariate/formers_multivariate_result_latest.txt', True).\
                drop_duplicates(subset=['model', 'lookback', 'future', 'pos','val','temp'],keep = 'last')
mv_lstms = parse_lstms('multivariate/result-lstm-multivariate.txt').\
                drop_duplicates(subset=['lookback', 'future'], keep = 'last')


## multivariate OHLC and Moving Averages##
mv_formers_ma = parse_results('multivariate/formers_multivariate_result_more_features.txt', True).\
                drop_duplicates(subset=['model', 'lookback', 'future', 'pos','val','temp'],keep = 'last')
mv_lstms_ma = parse_lstms('multivariate/result-lstm-multivariate-more-features.txt').\
                drop_duplicates(subset=['lookback', 'future'], keep = 'last')


##
df_seq_len = parse_results('understanding_seq_len.txt', True)

df_uv = slice_and_dice(uv_formers, uv_lstms)
df_mv = slice_and_dice(mv_formers, mv_lstms)
df_mv_ma = slice_and_dice(mv_formers_ma, mv_lstms_ma)

# %%
df_uv
# Out:
#      lookback  future    pos    val   temp  MSE-Autoformer  MAE-Autoformer  \
# 0           6       1   True   True   True        0.002861        0.046200
# 1           6       1   True   True  False        0.001956        0.028836
# 2           6       1   True  False   True        0.002035        0.031777
# 3           6       1  False   True   True        0.000731        0.019317
# 4           6       1  False   True  False        0.000700        0.018849
# ..        ...     ...    ...    ...    ...             ...             ...
# 654       672      12   True  False  False        0.204895        0.375747
# 655       672      24   True  False  False        0.162517        0.340614
# 656       672      96   True  False  False        0.072119        0.223650
# 657       672     192   True  False  False        0.106884        0.254196
# 658       672     336   True  False  False        0.168158        0.335231
#
#      RMSE-Autoformer  MAPE-Autoformer  MSPE-Autoformer  RSE-Autoformer  \
# 0           0.053490         0.019560         0.000529        0.106245
# 1           0.044225         0.012020         0.000350        0.087842
# 2           0.045116         0.013307         0.000363        0.089611
# 3           0.027039         0.008023         0.000128        0.053706
# 4           0.026450         0.007863         0.000124        0.052537
# ..               ...              ...              ...             ...
# 654         0.452653         0.170461         0.043955        1.555103
# 655         0.403134         0.154500         0.035051        1.387082
# 656         0.268549         0.099423         0.014545        0.933808
# 657         0.326931         0.115812         0.023484        1.145661
# 658         0.410070         0.151594         0.036546        1.447754
#
#      R2-Autoformer  train_time-Autoformer  test_time-Autoformer  \
# 0         0.988712             232.685127              1.221085
# 1         0.992284              96.161986              1.240438
# 2         0.991970             171.914533              1.223731
# 3         0.997116             248.008285              1.222289
# 4         0.997240             186.809782              1.225036
# ..             ...                    ...                   ...
# 654      -1.417169             436.578385              7.806420
# 655      -0.924099             772.729837              7.877082
# 656       0.127572             472.131348              8.225767
# 657      -0.324532             806.400100              8.651854
# 658      -1.139219             693.891350             10.087612
#
#      epochs-Autoformer  time_per_epoch-Autoformer  MSE-Informer  MAE-Informer  \
# 0                  1.0                 232.685127      0.003631      0.044440
# 1                  1.0                  96.161986      0.001678      0.029682
# 2                  1.0                 171.914533      6.103657      2.356894
# 3                  1.0                 248.008285      0.685541      0.697718
# 4                  1.0                 186.809782      0.021520      0.111250
# ..                 ...                        ...           ...           ...
# 654                3.0                 145.526128      0.023631      0.122012
# 655                6.0                 128.788306      0.031093      0.141942
# 656                3.0                 157.377116      0.088168      0.237438
# 657                5.0                 161.280020      0.356326      0.544537
# 658                4.0                 173.472837      0.565199      0.705528
#
#      RMSE-Informer  MAPE-Informer  MSPE-Informer  RSE-Informer  R2-Informer  \
# 0         0.060261       0.017408       0.000527      0.119693     0.985674
# 1         0.040968       0.011968       0.000267      0.081374     0.993378
# 2         2.470558       0.942935       0.902532      4.907152   -23.080144
# 3         0.827974       0.272650       0.098631      1.644565    -1.704595
# 4         0.146696       0.043353       0.002582      0.291376     0.915100
# ..             ...            ...            ...           ...          ...
# 654       0.153722       0.055235       0.005123      0.528117     0.721009
# 655       0.176333       0.064358       0.006802      0.606718     0.631757
# 656       0.296931       0.107753       0.019171      1.032496    -0.074402
# 657       0.596931       0.252276       0.082843      2.091814    -3.421142
# 658       0.751797       0.327958       0.131563      2.654222    -6.146185
#
#      train_time-Informer  test_time-Informer  epochs-Informer  \
# 0             225.288682            0.921379              1.0
# 1             216.788291            0.915424              1.0
# 2              93.362818            0.895015              1.0
# 3             157.477856            0.909348              1.0
# 4             272.250033            0.910206              1.0
# ..                   ...                 ...              ...
# 654          1021.032028            2.564678             13.0
# 655           811.601881            2.556803             10.0
# 656           689.574851            2.710274              8.0
# 657           420.041871            2.801190              4.0
# 658           357.890502            2.888904              3.0
#
#      time_per_epoch-Informer  MSE-Transformer  MAE-Transformer  \
# 0                 225.288682         0.005185         0.047305
# 1                 216.788291         0.003110         0.036018
# 2                  93.362818         5.913176         2.337085
# 3                 157.477856         0.007574         0.068106
# 4                 272.250033         0.011984         0.086059
# ..                       ...              ...              ...
# 654                78.540925         0.008984         0.074692
# 655                81.160188         0.013662         0.091113
# 656                86.196856         0.056055         0.196871
# 657               105.010468         0.093335         0.251252
# 658               119.296834              NaN              NaN
#
#      RMSE-Transformer  MAPE-Transformer      MSPE       RSE  R2-Transformer  \
# 0            0.072006          0.017195  0.000587  0.143023        0.979544
# 1            0.055766          0.013131  0.000353  0.110766        0.987731
# 2            2.431702          0.938520  0.887887  4.829975      -22.328657
# 3            0.087028          0.027081  0.001069  0.172860        0.970119
# 4            0.109472          0.033213  0.001613  0.217439        0.952720
# ..                ...               ...       ...       ...             ...
# 654          0.094784          0.033060  0.001795  0.325632        0.893930
# 655          0.116883          0.040471  0.002770  0.402165        0.838089
# 656          0.236759          0.090334  0.012720  0.823265        0.318947
# 657          0.305507          0.117771  0.022509  1.070584       -0.163524
# 658               NaN               NaN       NaN       NaN             NaN
#
#      train_time  test_time  epochs  time_per_epoch  MSE-LSTM  MAE-LSTM  \
# 0    201.543554   0.781403     1.0      201.543554       NaN       NaN
# 1    134.497079   0.787183     1.0      134.497079       NaN       NaN
# 2     85.108695   0.774238     1.0       85.108695       NaN       NaN
# 3    135.189872   0.800815     1.0      135.189872       NaN       NaN
# 4    134.899278   0.783467     1.0      134.899278       NaN       NaN
# ..          ...        ...     ...             ...       ...       ...
# 654  671.305218   3.058839     6.0      111.884203       NaN       NaN
# 655  576.939620   3.106985     5.0      115.387924       NaN       NaN
# 656  403.543515   3.227253     3.0      134.514505       NaN       NaN
# 657  434.955178   3.345510     3.0      144.985060       NaN       NaN
# 658         NaN        NaN     NaN             NaN       NaN       NaN
#
#      RMSE-LSTM  MAPE-LSTM  R2-LSTM
# 0          NaN        NaN      NaN
# 1          NaN        NaN      NaN
# 2          NaN        NaN      NaN
# 3          NaN        NaN      NaN
# 4          NaN        NaN      NaN
# ..         ...        ...      ...
# 654        NaN        NaN      NaN
# 655        NaN        NaN      NaN
# 656        NaN        NaN      NaN
# 657        NaN        NaN      NaN
# 658        NaN        NaN      NaN
#
# [659 rows x 43 columns]

# %% [markdown]
# ## MultiVariate - UniVariate ##

# %%
pd.set_option('display.expand_frame_repr', False)
# model = 'Autoformer'
model = 'Informer'
# model = 'Informer'
mv_frame = mv_formers_ma.copy(deep=True)
df_uni_mv = uv_formers[["model","lookback", "future", "pos", "val", "temp", "MSE", "MAE"]].\
            merge(mv_frame, how = "left", on=["model","lookback", "future", "pos", "val", "temp"], \
                              suffixes=('-Uni', '-multi'))
df_uni_mv = df_uni_mv.dropna()# lookback = 6
if model == 'Transformer':
    pos, val, temp = 'True', 'False', 'False'
elif model == 'Informer':
    pos, val, temp = 'True', 'True', 'True'
elif model == 'Autoformer':
    pos, val, temp = 'False', 'True', 'True'
 
for lookback in [24, 48, 96, 168, 336]:   
    try:
        result_df = df_uni_mv[(df_uni_mv['model'] == model)\
                  & (df_uni_mv['lookback'] == lookback)\
                  & (df_uni_mv['pos'] == pos)\
                  & (df_uni_mv['val'] == val)\
                  & (df_uni_mv['temp'] == temp)]
#         result_df['improvement'] = (result_df['MAE-Uni'] - result_df['MAE-multi'])*100/result_df['MAE-Uni']
#         result_df *= 10
#         print(len(result_df))
#         print("-------")
        if len(result_df):
            ax = result_df.plot.bar(x='future', y=['MAE-Uni','MAE-multi'],figsize=(10,5))
            ax.set_title(model + "- lookback "+ str(lookback) )
    except Exception as e:
        print(e)

# %% [markdown]
# ## time comparison ##

# %%
pd.set_option('display.expand_frame_repr', True)
plt.rcParams["figure.dpi"] = 100
# for lookback in [6, 12, 24, 48, 72, 96, 120, 144, 168, 192, 336, 504, 672,720]:
for lookback in [24, 96]:
    columns_time = ['test_time','test_time-Informer','test_time-Autoformer']
    columns_epoch = ['epochs','epochs-Informer','epochs-Autoformer']
    columns = ['time_per_epoch','time_per_epoch-Informer','time_per_epoch-Autoformer']
    time_df = df_uv[['lookback', 'future', 'pos', 'val', 'temp',\
                      'time_per_epoch-Autoformer','time_per_epoch-Informer','time_per_epoch',\
                      'test_time-Autoformer','test_time-Informer','test_time',\
                      'train_time-Autoformer','train_time-Informer','train_time',\
                      'epochs-Autoformer','epochs-Informer','epochs']]
    time_df = time_df[time_df['epochs']>2]
    ## Informer ##
    time_inf = time_df[(time_df['lookback'] == lookback) & (time_df['pos'] == 'True')\
            & (time_df['val'] == 'True') & (time_df['temp'] == 'True')]\
            [['lookback', 'future', 'time_per_epoch-Informer','epochs-Informer','test_time-Informer']]
    ## Transformer ##
    time_tra = time_df[(time_df['lookback'] == lookback) & (time_df['pos'] == 'True')\
            & (time_df['val'] == 'False') & (time_df['temp'] == 'False')]\
            [['lookback', 'future', 'time_per_epoch','epochs','test_time']]
    ## Autoformer ##
    time_aut = time_df[(time_df['lookback'] == lookback) & (time_df['pos'] == 'False')\
            & (time_df['val'] == 'True') & (time_df['temp'] == 'True')]\
            [['lookback', 'future', 'time_per_epoch-Autoformer','epochs-Autoformer','test_time-Autoformer']]
    time_formers = time_inf.merge(time_tra, how = "left", on=["lookback", "future"],suffixes=('-Autoformer', '-Informer'))\
                 .merge(time_aut, how = "left", on=["lookback", "future"],suffixes=('_ello', '-Transformer'))
    # time_formers
    time_formers = time_formers.round(2)
    time_formers = time_formers[time_formers['future']<=336]
#     print(time_formers)
    ax = time_formers.plot(x='future', y=columns,style='X-')
    ax.set_ylabel('seconds')
    ax.legend(['Transformer','Informer','Autoformer'])
    ax.set_title('Time Per Epoch - lookback ' + str(lookback))
    
    ax = time_formers.plot(x='future', y=columns_time,style='X-')
    ax.set_ylabel('seconds')
    ax.legend(['Transformer','Informer','Autoformer'])
    ax.set_title('Inference - lookback ' + str(lookback))
    
    ax = time_formers.plot.bar(x='future', y=columns_epoch,style='X-')
    ax.set_ylabel('epochs')
    ax.legend(['Transformer','Informer','Autoformer'])
    ax.set_title('Number Epoch - lookback ' + str(lookback))
#     ax = time_formers.plot(x='future', y=columns_epoch,style='X-')
#     ax.set_ylabel('Epochs')
#     ax.bar_label(ax.containers[0], rotation = 45)
#     ax.bar_label(ax.containers[1], rotation = 45)
#     ax.bar_label(ax.containers[2], rotation = 45)
#     ax.legend(['Transformer','Informer','Autoformer'])
#     ax.set_title('Epoch - lookback ' + str(lookback))



#     ax.bar_label(ax.containers[0], rotation = 45)
#     ax.bar_label(ax.containers[1], rotation = 45)
#     ax.bar_label(ax.containers[2], rotation = 45)

# %% [markdown]
# ## SHOW DIFFERENT EMBEDDINGS DATAFRAME ##

# %%
pd.set_option('display.expand_frame_repr', True)
def show_best_parameters_for_model(df, model = 'Transformer'):
    df = df.copy(deep=True)
    for lookback in [24, 48, 96, 336, 720]:
#     for lookback in [96]:
        for future in [1, 12, 24, 96, 192, 336, 720]:
            try:
                df_ = df[(df['lookback'] == lookback) & (df['future'] == future)]\
                      [['lookback','future','pos','val','temp','MAE-' + model]].reset_index(drop=True)
                res = df_.iloc[df_['MAE-' + model].idxmin()]
#                 df_['MAE-' + model] *= 10
                print(df_)
                print(list(res))
                print("=============")
            except Exception as e:
                print('Lookback {} and future {} not found'.format(lookback, future))


show_best_parameters_for_model(df_uv, model = 'Transformer')
# Out:
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        24       1   True   True   True         0.039775
# 1        24       1   True   True  False         0.030012
# 2        24       1   True  False   True         0.033541
# 3        24       1  False   True   True         0.066040
# 4        24       1  False   True  False         0.082957
# 5        24       1  False  False   True         2.237234
# 6        24       1   True  False  False         0.029543
# [24, 1, 'True', 'False', 'False', 0.02954257]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        24      12   True   True   True         0.055993
# 1        24      12   True   True  False         0.053556
# 2        24      12   True  False   True         0.059357
# 3        24      12  False   True   True         0.458341
# 4        24      12  False   True  False         0.113770
# 5        24      12  False  False   True         2.247545
# 6        24      12   True  False  False         0.058979
# [24, 12, 'True', 'True', 'False', 0.05355578]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        24      24   True   True   True         0.075139
# 1        24      24   True   True  False         0.070653
# 2        24      24   True  False   True         0.080414
# 3        24      24  False   True   True         0.490577
# 4        24      24  False   True  False         0.119719
# 5        24      24  False  False   True         2.311731
# 6        24      24   True  False  False         0.069736
# [24, 24, 'True', 'False', 'False', 0.06973572]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        24      96   True   True   True         0.171121
# 1        24      96   True   True  False         0.138540
# 2        24      96   True  False   True         0.148062
# 3        24      96  False   True   True         0.510820
# 4        24      96  False   True  False         0.173788
# 5        24      96  False  False   True         2.372576
# 6        24      96   True  False  False         0.155944
# [24, 96, 'True', 'True', 'False', 0.13854015]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        24     192   True   True   True         0.216234
# 1        24     192   True   True  False         0.212253
# 2        24     192   True  False   True         0.258437
# 3        24     192  False   True   True         0.389013
# 4        24     192  False   True  False         0.217036
# 5        24     192  False  False   True         2.225690
# 6        24     192   True  False  False         0.211116
# [24, 192, 'True', 'False', 'False', 0.21111564]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        24     336   True   True   True         0.380969
# 1        24     336   True   True  False         0.302465
# 2        24     336   True  False   True         0.426648
# 3        24     336  False   True   True         0.402168
# 4        24     336  False   True  False         0.313829
# 5        24     336  False  False   True         2.234942
# 6        24     336   True  False  False         0.321578
# [24, 336, 'True', 'True', 'False', 0.30246472]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        24     720   True   True   True         0.725959
# 1        24     720   True   True  False         0.401669
# 2        24     720   True  False   True         0.523905
# 3        24     720  False   True   True         0.765414
# 4        24     720  False   True  False         0.408568
# 5        24     720  False  False   True         1.732526
# 6        24     720   True  False  False         0.448717
# [24, 720, 'True', 'True', 'False', 0.40166911]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        48       1   True   True   True         0.032096
# 1        48       1   True   True  False         0.027172
# 2        48       1   True  False   True         0.026460
# 3        48       1  False   True   True         0.050105
# 4        48       1  False   True  False         0.066590
# 5        48       1  False  False   True         2.179630
# 6        48       1   True  False  False         0.025899
# [48, 1, 'True', 'False', 'False', 0.02589934]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        48      12   True   True   True         0.054726
# 1        48      12   True   True  False         0.054010
# 2        48      12   True  False   True         0.063691
# 3        48      12  False   True   True         0.431867
# 4        48      12  False   True  False         0.094193
# 5        48      12  False  False   True         2.266790
# 6        48      12   True  False  False         0.060540
# [48, 12, 'True', 'True', 'False', 0.05400956]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        48      24   True   True   True         0.078073
# 1        48      24   True   True  False         0.075293
# 2        48      24   True  False   True         0.074349
# 3        48      24  False   True   True         0.451463
# 4        48      24  False   True  False         0.102577
# 5        48      24  False  False   True         2.271888
# 6        48      24   True  False  False         0.074303
# [48, 24, 'True', 'False', 'False', 0.07430311]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        48      96   True   True   True         0.153305
# 1        48      96   True   True  False         0.144048
# 2        48      96   True  False   True         0.145032
# 3        48      96  False   True   True         0.320984
# 4        48      96  False   True  False         0.161392
# 5        48      96  False  False   True         2.264728
# 6        48      96   True  False  False         0.125186
# [48, 96, 'True', 'False', 'False', 0.12518592]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        48     192   True   True   True         0.254596
# 1        48     192   True   True  False         0.240605
# 2        48     192   True  False   True         0.260319
# 3        48     192  False   True   True         0.352639
# 4        48     192  False   True  False         0.207663
# 5        48     192  False  False   True         2.169522
# 6        48     192   True  False  False         0.231211
# [48, 192, 'False', 'True', 'False', 0.20766304]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        48     336   True   True   True         0.480821
# 1        48     336   True   True  False         0.249559
# 2        48     336   True  False   True         0.347414
# 3        48     336  False   True   True         0.616092
# 4        48     336  False   True  False         0.237020
# 5        48     336  False  False   True         2.044241
# 6        48     336   True  False  False         0.299853
# [48, 336, 'False', 'True', 'False', 0.23702013]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        48     720   True   True   True         0.608220
# 1        48     720   True   True  False         0.492891
# 2        48     720   True  False   True         0.615245
# 3        48     720  False   True   True         0.725686
# 4        48     720  False   True  False         0.435024
# 5        48     720  False  False   True         1.750834
# 6        48     720   True  False  False         0.466618
# [48, 720, 'False', 'True', 'False', 0.43502364]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        96       1   True   True   True         0.034176
# 1        96       1   True   True  False         0.024342
# 2        96       1   True  False   True         0.033232
# 3        96       1  False   True   True         0.050268
# 4        96       1  False   True  False         0.028737
# 5        96       1  False  False   True         2.189990
# 6        96       1   True  False  False         0.032570
# [96, 1, 'True', 'True', 'False', 0.02434177]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        96      12   True   True   True         0.058164
# 1        96      12   True   True  False         0.056185
# 2        96      12   True  False   True         0.056948
# 3        96      12  False   True   True         0.403588
# 4        96      12  False   True  False         0.183604
# 5        96      12  False  False   True         2.209485
# 6        96      12   True  False  False         0.062878
# [96, 12, 'True', 'True', 'False', 0.05618537]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        96      24   True   True   True         0.089888
# 1        96      24   True   True  False         0.075158
# 2        96      24   True  False   True         0.088647
# 3        96      24  False   True   True         0.474930
# 4        96      24  False   True  False         0.117634
# 5        96      24  False  False   True         2.043595
# 6        96      24   True  False  False         0.083330
# [96, 24, 'True', 'True', 'False', 0.07515775]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        96      96   True   True   True         0.217827
# 1        96      96   True   True  False         0.151437
# 2        96      96   True  False   True         0.159372
# 3        96      96  False   True   True         0.464656
# 4        96      96  False   True  False         0.177323
# 5        96      96  False  False   True         2.121836
# 6        96      96   True  False  False         0.150096
# [96, 96, 'True', 'False', 'False', 0.15009575]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        96     192   True   True   True         0.270745
# 1        96     192   True   True  False         0.216310
# 2        96     192   True  False   True         0.212521
# 3        96     192  False   True   True         0.503601
# 4        96     192  False   True  False         0.256311
# 5        96     192  False  False   True         2.167631
# 6        96     192   True  False  False         0.235373
# [96, 192, 'True', 'False', 'True', 0.21252124]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        96     336   True   True   True         0.480116
# 1        96     336   True   True  False         0.340983
# 2        96     336   True  False   True         0.424143
# 3        96     336  False   True   True         0.692692
# 4        96     336  False   True  False         0.340433
# 5        96     336  False  False   True         2.082496
# 6        96     336   True  False  False         0.276260
# [96, 336, 'True', 'False', 'False', 0.27625957]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0        96     720   True   True   True         0.727654
# 1        96     720   True   True  False         0.590267
# 2        96     720   True  False   True         0.672791
# 3        96     720  False   True   True         0.838257
# 4        96     720  False   True  False         0.455606
# 5        96     720  False  False   True         1.907077
# 6        96     720   True  False  False         0.452003
# [96, 720, 'True', 'False', 'False', 0.4520027]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0       336       1   True   True   True         0.047093
# 1       336       1   True   True  False         0.033452
# 2       336       1   True  False   True         0.030587
# 3       336       1  False   True   True         0.046642
# 4       336       1  False   True  False         0.050674
# 5       336       1  False  False   True         1.814925
# 6       336       1   True  False  False         0.036961
# [336, 1, 'True', 'False', 'True', 0.03058719]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0       336      12   True   True   True         0.079957
# 1       336      12   True   True  False         0.067771
# 2       336      12   True  False   True         0.070688
# 3       336      12  False   True   True         0.313319
# 4       336      12  False   True  False         0.106326
# 5       336      12  False  False   True         2.222642
# 6       336      12   True  False  False         0.060461
# [336, 12, 'True', 'False', 'False', 0.06046058]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0       336      24   True   True   True         0.096271
# 1       336      24   True   True  False         0.079071
# 2       336      24   True  False   True         0.078092
# 3       336      24  False   True   True         0.415553
# 4       336      24  False   True  False         0.125505
# 5       336      24  False  False   True         1.756768
# 6       336      24   True  False  False         0.073977
# [336, 24, 'True', 'False', 'False', 0.07397695]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0       336      96   True   True   True         0.237935
# 1       336      96   True   True  False         0.203038
# 2       336      96   True  False   True         0.179167
# 3       336      96  False   True   True         0.465517
# 4       336      96  False   True  False         0.197246
# 5       336      96  False  False   True         1.740290
# 6       336      96   True  False  False         0.145900
# [336, 96, 'True', 'False', 'False', 0.14589989]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0       336     192   True   True   True         0.246708
# 1       336     192   True   True  False         0.261231
# 2       336     192   True  False   True         0.231195
# 3       336     192  False   True   True         0.581978
# 4       336     192  False   True  False         0.277396
# 5       336     192  False  False   True         1.770167
# 6       336     192   True  False  False         0.198750
# [336, 192, 'True', 'False', 'False', 0.19874972]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0       336     336   True   True   True         0.487769
# 1       336     336   True   True  False         0.479674
# 2       336     336   True  False   True         0.461739
# 3       336     336  False   True   True         0.681782
# 4       336     336  False   True  False         0.515618
# 5       336     336  False  False   True         2.126778
# 6       336     336   True  False  False         0.377922
# [336, 336, 'True', 'False', 'False', 0.37792233]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0       336     720   True   True   True         0.643953
# 1       336     720   True   True  False         0.524055
# 2       336     720   True  False   True         0.815527
# 3       336     720  False   True   True         0.926534
# 4       336     720  False   True  False         0.699099
# 5       336     720  False  False   True         1.607550
# 6       336     720   True  False  False         0.712942
# [336, 720, 'True', 'True', 'False', 0.52405518]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0       720       1   True   True   True         0.039751
# 1       720       1   True   True  False              NaN
# 2       720       1   True  False   True              NaN
# 3       720       1  False   True   True         0.032772
# 4       720       1  False   True  False         0.039151
# 5       720       1  False  False   True         1.968967
# [720, 1, 'False', 'True', 'True', 0.03277158]
# =============
#    lookback  future    pos    val   temp  MAE-Transformer
# 0       720      12   True   True   True              NaN
# 1       720      12   True   True  False              NaN
# 2       720      12   True  False   True              NaN
# 3       720      12  False   True   True              NaN
# 4       720      12  False   True  False         0.228558
# 5       720      12  False  False   True         2.196320
# [720, 12, 'False', 'True', 'False', 0.22855803]
# =============
# Lookback 720 and future 24 not found
# Lookback 720 and future 96 not found
# Lookback 720 and future 192 not found
# Lookback 720 and future 336 not found
# Lookback 720 and future 720 not found

# %% [markdown]
# ## DEFAULT EMBEDDINGS SHOW DATAFRAME ##

# %%
def show_by_mse_mae(df_, *args, x_axis = 'future'):
    """."""
    x_axis = x_axis
    df_ = df_.copy(deep=True)
    
    if x_axis ==  'lookback':
        frame_by = 'future'
        loopby = [1, 12, 24, 96, 192, 336, 720]
    elif x_axis == 'future':
        frame_by = 'lookback'
        loopby = [24, 48, 72, 96, 120, 144, 168, 336, 720]
#         loopby = [6]
        

    for i in loopby:
        autoformer= df_[(df_[frame_by] == i) & (df_['pos'] == 'False') & (df_['temp'] == 'True')\
                    & (df_['val'] == 'True')][['lookback','future','MSE-Autoformer', 'MAE-Autoformer','MSE-LSTM',\
                                                  'MAE-LSTM']]
        informer = df_[(df_[frame_by] == i) & (df_['pos'] == 'True') & (df_['temp'] == 'True')\
                     & (df_['val'] == 'True')][['lookback','future','MSE-Informer', 'MAE-Informer']]
        transformer = df_[(df_[frame_by] == i) & (df_['pos'] == 'True') & (df_['temp'] == 'False')\
                     & (df_['val'] == 'False')][['lookback','future','MSE-Transformer', 'MAE-Transformer']]
        df_merge = informer.merge(transformer, how = "left", on=["lookback", "future"], suffixes=('_Inf', '_Tra'))\
                   .merge(autoformer, how = "left", on=["lookback", "future"], suffixes=('_ello', '_auto'))
#         df_merge *= 10
        df_merge = df_merge.round(5)
        print("lookback ", i)
        df_merge = df_merge.drop(columns=['lookback'])
        df_merge = df_merge.round(5)
        print(df_merge.to_string(index=False))
#         print("=========")

show_by_mse_mae(df_mv_ma, x_axis='future')
# Out:
# lookback  24
#  future  MSE-Informer  MAE-Informer  MSE-Transformer  MAE-Transformer  MSE-Autoformer  MAE-Autoformer  MSE-LSTM  MAE-LSTM
#       1       0.00722       0.05791          0.00234          0.03790         0.00131         0.02479   0.00799   0.07043
#      12       0.02510       0.12016          0.00738          0.06178         0.00544         0.04974   0.05518   0.20645
#      24       0.03297       0.14666          0.01630          0.10075         0.01039         0.06973   0.06636   0.22716
#      96       0.07597       0.21703          0.08092          0.23158         0.03107         0.12877   0.10312   0.28071
#     192       0.23505       0.40432          0.26964          0.42045         0.05399         0.17543   0.29209   0.47659
#     336       0.36310       0.49676          0.34774          0.50455         0.09170         0.23696   0.32330   0.47478
# lookback  48
#  future  MSE-Informer  MAE-Informer  MSE-Transformer  MAE-Transformer  MSE-Autoformer  MAE-Autoformer  MSE-LSTM  MAE-LSTM
#       1       0.03136       0.13770          0.00888          0.08037         0.00141         0.02615   0.01171   0.08610
#      12       0.03832       0.15502          0.00608          0.05630         0.00613         0.05456   0.01404   0.09468
#      24       0.03072       0.13770          0.01817          0.10774         0.01129         0.07437   0.06813   0.23897
#      96       0.09959       0.24884          0.06418          0.20134         0.03525         0.13996   0.12828   0.31688
#     192       0.29038       0.42164          0.13144          0.28070         0.05894         0.18586   0.29382   0.48151
#     336       0.31958       0.48445          0.20094          0.35882         0.10310         0.25401   0.46292   0.61302
# lookback  72
# Empty DataFrame
# Columns: [MSE-Informer, MAE-Informer, MSE-Transformer, MAE-Transformer, future, MSE-Autoformer, MAE-Autoformer, MSE-LSTM, MAE-LSTM]
# Index: []
# lookback  96
#  future  MSE-Informer  MAE-Informer  MSE-Transformer  MAE-Transformer  MSE-Autoformer  MAE-Autoformer  MSE-LSTM  MAE-LSTM
#       1       0.03001       0.12044          0.00568          0.05744         0.00139         0.02767   0.01741   0.11287
#      12       0.03236       0.13846          0.01353          0.09445         0.00777         0.06495   0.07105   0.24231
#      24       0.04960       0.18071          0.02795          0.14348         0.01297         0.08243   0.13092   0.31951
#      96       0.13145       0.28866          0.10684          0.27589         0.04280         0.16044   0.12371   0.31076
#     192       0.49386       0.58355          0.09978          0.25421         0.06541         0.19934   0.30304   0.49246
#     336       0.52079       0.61798          0.20621          0.34887         0.10460         0.25882   0.51357   0.65667
# lookback  120
# Empty DataFrame
# Columns: [MSE-Informer, MAE-Informer, MSE-Transformer, MAE-Transformer, future, MSE-Autoformer, MAE-Autoformer, MSE-LSTM, MAE-LSTM]
# Index: []
# lookback  144
# Empty DataFrame
# Columns: [MSE-Informer, MAE-Informer, MSE-Transformer, MAE-Transformer, future, MSE-Autoformer, MAE-Autoformer, MSE-LSTM, MAE-LSTM]
# Index: []
# lookback  168
# Empty DataFrame
# Columns: [MSE-Informer, MAE-Informer, MSE-Transformer, MAE-Transformer, future, MSE-Autoformer, MAE-Autoformer, MSE-LSTM, MAE-LSTM]
# Index: []
# lookback  336
#  future  MSE-Informer  MAE-Informer  MSE-Transformer  MAE-Transformer  MSE-Autoformer  MAE-Autoformer  MSE-LSTM  MAE-LSTM
#       1       0.21530       0.43439          0.01004          0.08625         0.01309         0.09031   0.01033   0.08079
#      12       0.36561       0.55985          0.03088          0.15528         0.01823         0.10648   0.07469   0.23962
#      24       0.63680       0.73892          0.03316          0.15338         0.02956         0.13111   0.12671   0.32169
#      96       0.68681       0.75865          0.11047          0.26398         0.10295         0.26954   0.12856   0.31572
#     192       0.73406       0.76245          0.46696          0.60230         0.19574         0.38041   0.31218   0.50918
#     336       0.81445       0.80319          0.21472          0.36990         0.30907         0.47023   0.26015   0.43417
# lookback  720
# Empty DataFrame
# Columns: [MSE-Informer, MAE-Informer, MSE-Transformer, MAE-Transformer, future, MSE-Autoformer, MAE-Autoformer, MSE-LSTM, MAE-LSTM]
# Index: []

# %% [markdown]
# ## BEST EMBEDDINGS SHOW DATAFRAME ##

# %%
pd.set_option('display.expand_frame_repr', False)
def show_by_mse_mae(df_):
    """."""
    df_ = df_.copy(deep=True)
    data = defaultdict(list)
    for lookback in [24, 48, 72, 96, 336, 720]:
        for future in [1, 12, 24, 96, 192, 336, 720]:
            former= df_[(df_['lookback'] == lookback) & (df_['future'] == future)]\
                        [['lookback','future','pos','val','temp','MSE-Autoformer', 'MAE-Autoformer',\
                          'MSE-Informer', 'MAE-Informer',\
                          'MSE-Transformer','MAE-Transformer']]
            data['lookback'].append(lookback)
            data['future'].append(future)
            data['MSE-Info'].append(former['MSE-Informer'].min())
            data['MAE-Info'].append(former['MAE-Informer'].min())
            data['MSE-Trans'].append(former['MSE-Transformer'].min())
            data['MAE-Trans'].append(former['MAE-Transformer'].min())
            data['MSE-Auto'].append(former['MSE-Autoformer'].min())
            data['MAE-Auto'].append(former['MAE-Autoformer'].min())
#             print(former)
#             print("------")
    return pd.DataFrame.from_dict(data)
return_df = show_by_mse_mae(df_mv_ma)
# return_df *= 10
print(return_df.to_string(index=False))
# Out:
#  lookback  future  MSE-Info  MAE-Info  MSE-Trans  MAE-Trans  MSE-Auto  MAE-Auto
#        24       1  0.004675  0.054113   0.002052   0.033339  0.001313  0.024794
#        24      12  0.006806  0.060006   0.006677   0.058884  0.004694  0.045573
#        24      24  0.015588  0.094003   0.015435   0.096296  0.009391  0.065371
#        24      96  0.070963  0.207507   0.035492   0.140452  0.029774  0.124870
#        24     192  0.094496  0.243168   0.193753   0.338556  0.053348  0.174466
#        24     336  0.322546  0.468153   0.311534   0.458677  0.090440  0.234584
#        24     720       NaN       NaN        NaN        NaN       NaN       NaN
#        48       1  0.014894  0.099702   0.003249   0.041671  0.001409  0.026097
#        48      12  0.014377  0.092971   0.006081   0.056302  0.005762  0.053601
#        48      24  0.015931  0.093191   0.017032   0.102944  0.009443  0.067727
#        48      96  0.099587  0.248836   0.064180   0.201342  0.031913  0.130820
#        48     192  0.264511  0.421636   0.116127   0.260219  0.058345  0.184629
#        48     336  0.319578  0.484450   0.200938   0.356394  0.092514  0.240585
#        48     720       NaN       NaN        NaN        NaN       NaN       NaN
#        72       1       NaN       NaN        NaN        NaN       NaN       NaN
#        72      12       NaN       NaN        NaN        NaN       NaN       NaN
#        72      24       NaN       NaN        NaN        NaN       NaN       NaN
#        72      96       NaN       NaN        NaN        NaN       NaN       NaN
#        72     192       NaN       NaN        NaN        NaN       NaN       NaN
#        72     336       NaN       NaN        NaN        NaN       NaN       NaN
#        72     720       NaN       NaN        NaN        NaN       NaN       NaN
#        96       1  0.021983  0.112134   0.005679   0.057440  0.001388  0.027671
#        96      12  0.017486  0.099515   0.010830   0.081953  0.007770  0.064951
#        96      24  0.026084  0.124721   0.027955   0.143477  0.012968  0.082433
#        96      96  0.102707  0.251833   0.106842   0.275885  0.038238  0.146339
#        96     192  0.461148  0.575083   0.099775   0.254212  0.065414  0.199338
#        96     336  0.520790  0.617983   0.113507   0.276325  0.103788  0.257294
#        96     720       NaN       NaN        NaN        NaN       NaN       NaN
#       336       1  0.075364  0.247806   0.007889   0.074853  0.011427  0.084943
#       336      12  0.163654  0.367910   0.030885   0.155278  0.018229  0.106480
#       336      24  0.110214  0.290673   0.033162   0.153382  0.023914  0.118513
#       336      96  0.559638  0.692165   0.110474   0.263982  0.053407  0.178209
#       336     192  0.366132  0.526299   0.307059   0.467466  0.088444  0.243064
#       336     336  0.504538  0.625921   0.214720   0.369896  0.142010  0.304998
#       336     720       NaN       NaN        NaN        NaN       NaN       NaN
#       720       1       NaN       NaN        NaN        NaN       NaN       NaN
#       720      12       NaN       NaN        NaN        NaN       NaN       NaN
#       720      24       NaN       NaN        NaN        NaN       NaN       NaN
#       720      96       NaN       NaN        NaN        NaN       NaN       NaN
#       720     192       NaN       NaN        NaN        NaN       NaN       NaN
#       720     336       NaN       NaN        NaN        NaN       NaN       NaN
#       720     720       NaN       NaN        NaN        NaN       NaN       NaN

# %% [markdown]
# ## SHOW EMBEDDING COMBINATIONS ##

# %%
df_org.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df_org.head()
#
# NameError: name 'df_org' is not defined

# %%
columns

# %%
def show_embeddings_comb(df_, columns, lookback_list):
    df_ = df_.copy(deep=True)
    loopby = [24, 48, 72, 96, 336, 720]

    for lookback in lookback_list:
        print(" "*40 + "============= LOOKBACK {} ==============".format(lookback))
        for pos in ["True", "False"]:
            for val in ["True", "False"]:
                for temp in ["True", "False"]:
                    if pos == "False" and val == "False" and temp == "False":
                        continue
                        
                    ax = df_[(df_['lookback'] == lookback) & (df_['pos'] == pos) & (df_['temp'] == temp)\
                             & (df_['val'] == val)]\
                         .plot.bar(x='future', y=['MAE-Transformer', 'MAE-Informer'], figsize=(15,5))
                    
#                     for y in range(0, len(columns)):
#                         ax.bar_label(ax.containers[y], rotation = 90)
                    
                    if pos == "False" and val == "True" and temp == "True":
                        ax.set_title("pos " + pos + ", Val " + val + ", Temp " + temp + " ==> Default embeddings for AutoFormer")
                    elif pos == "True" and val == "True" and temp == "True":
                        ax.set_title("pos " + pos + ", Val " + val + ", Temp " + temp + " ==> Default embeddings for InFormer")
                    else:
                        ax.set_title("pos " + pos + ", Val " + val + ", Temp " + temp) 
                    plt.show()
# show_embeddings_comb(df_org, columns, [96])

# %%
SMALL_SIZE = 20
MEDIUM_SIZE = 26
BIGGER_SIZE = 26

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

def show_by_default_embeddings(df_, *args, x_axis = 'future', metric = 'mae'):
    """."""
    x_axis = x_axis
    df_ = df_.copy(deep=True)
    columns = list(args)
    
    if x_axis ==  'lookback':
        frame_by = 'future'
        loopby = [1, 12, 24, 96, 192, 336, 720]
    elif x_axis == 'future':
        frame_by = 'lookback'
#         loopby = [6, 12, 24, 48, 72, 96, 120, 144, 168, 192, 336, 504, 672,720]
        loopby = [24, 48, 96, 336]
        

    for i in loopby:
        autoformer= df_[(df_[frame_by] == i) & (df_['pos'] == 'False') & (df_['temp'] == 'True')\
                    & (df_['val'] == 'True')][['lookback','future',columns[2],columns[3]]]
        informer = df_[(df_[frame_by] == i) & (df_['pos'] == 'True') & (df_['temp'] == 'True')\
                     & (df_['val'] == 'True')][['lookback','future',columns[1]]]
        transformer = df_[(df_[frame_by] == i) & (df_['pos'] == 'True') & (df_['temp'] == 'False')\
                     & (df_['val'] == 'False')][['lookback','future',columns[0]]]
        df_merge = informer.merge(transformer, how = "left", on=["lookback", "future"], suffixes=('_Inf', '_Tra'))\
                   .merge(autoformer, how = "left", on=["lookback", "future"], suffixes=('_ello', '_auto'))
#         df_merge[columns] *= 10
        df_merge = df_merge.round(3)
#         print(df_merge)
#         print("=========")
        ax = df_merge.plot.bar(x=x_axis, y=['MAE-Transformer','MAE-LSTM'], figsize=(20,7))
#         for y in range(0, len(columns)):
#             ax.bar_label(ax.containers[y], rotation = 60)
        ax.set_title(frame_by.upper() + " "+ str(i))
        ax.set_ylabel(metric.upper())

        

def show(df_, *args, x_axis = 'lookback', pos='True', val='False', temp='False'):
    """."""
    x_axis = x_axis
    df_ = df_.copy(deep=True)
    columns = list(args) 
#     df_[columns] *= 100
    df_ = df_.round(2)
    
    if x_axis ==  'lookback':
        frame_by = 'future'
        loopby = [1, 12, 24, 96, 192, 336, 720]
    elif x_axis == 'future':
        frame_by = 'lookback'
        loopby = [6, 12, 24, 48, 72, 96, 120, 144, 168, 192, 336, 504, 672,720]

    for i in loopby:
        ax = df_[(df_[frame_by] == i) & (df_['pos'] == pos) & (df_['temp'] == temp) 
               & (df_['val'] == val)]\
              .plot.bar(x=x_axis, y=columns, figsize=(15,5))
        for y in range(0, len(columns)):
            ax.bar_label(ax.containers[y], rotation = 60)
        ax.set_title(frame_by.upper() + " "+ str(i))

        
def show_embeddings_comb(df_, columns, lookback_list):
    df_ = df_.copy(deep=True)
#     df_[columns] *= 100
#     df_ = df_.round(2)
    

    for lookback in lookback_list:
        print(" "*40 + "============= LOOKBACK {} ==============".format(lookback))
        for pos in ["True", "False"]:
            for val in ["True", "False"]:
                for temp in ["True", "False"]:
                    if pos == "False" and val == "False" and temp == "False":
                        continue
                        
                    ax = df_[(df_['lookback'] == lookback) & \
                             (df_['pos'] == pos) & (df_['temp'] == temp) & (df_['val'] == val)]\
                         .plot.bar(x='future', y=columns, figsize=(15,5))
                    
                    for y in range(0, len(columns)):
                        ax.bar_label(ax.containers[y], rotation = 90)
                    
                    if pos == "False" and val == "True" and temp == "True":
                        ax.set_title("pos " + pos + ", Val " + val + ", Temp " + temp + " ==> Default embeddings for AutoFormer")
                    elif pos == "True" and val == "True" and temp == "True":
                        ax.set_title("pos " + pos + ", Val " + val + ", Temp " + temp + " ==> Default embeddings for InFormer")
                    else:
                        ax.set_title("pos " + pos + ", Val " + val + ", Temp " + temp) 
                    plt.show()

# %%
# plt.rcParams["figure.dpi"] = 140
pos, val, temp = 'True', 'False', 'True'
metric = 'MAE'
columns = list(map(lambda x: metric + x, ['-Transformer','-Informer', '-Autoformer', '-LSTM']))
show_by_default_embeddings(df_mv_ma, *columns, x_axis='future', metric=metric)
# show(df_org, *columns, x_axis='future', pos = pos, val = val, temp = temp) 
# for lookback in [6, 12, 24, 48, 72, 96, 120, 144, 168, 192, 336, 504, 672,720]:
# show_embeddings_comb(df_org, columns, [96, 120])

# %%
# import torch
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0
plt.figure(figsize=(5,5))
plt.imshow(subsequent_mask(15)[0],cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 8>()
#       6     return torch.from_numpy(subsequent_mask) == 0
#       7 plt.figure(figsize=(5,5))
# ----> 8 plt.imshow(subsequent_mask(15)[0],cmap='gray')
#
# Input In [13], in subsequent_mask(size)
#       4 attn_shape = (1, size, size)
#       5 subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
# ----> 6 return torch.from_numpy(subsequent_mask) == 0
#
# NameError: name 'torch' is not defined

# %%
# df_org[(df_org['mae_LSTM'] < df_org['mae_Tra']) \
#        & (df_org['mae_LSTM'] < df_org['mae_Auto']) \
#        & (df_org['mae_LSTM'] < df_org['mae_Inf'])].\
#         sort_values(['lookback','future'])\
#      [['lookback', 'future', 'pos', 'val', 'temp','mae_Tra','mae_Auto','mae_Inf','mae_LSTM']]
